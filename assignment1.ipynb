# %% [markdown]
# <a href="https://colab.research.google.com/github/Raykiai/DataAnalysis_Track/blob/main/assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

import pandas as pandasForSortingCSV

import matplotlib.pyplot as plt
sns.set(color_codes=True)

# %%
kcse = pd.read_csv('KCSE_2016.csv')

# %% [markdown]
# View Dataset

# %%
kcse.head()
# Out:
#          Gender     A    A-     B+      B  ...     C-     D+       D      D-      E
# 0  FEMALE(2016)    58  2685   6581  10204  ...  30979  41632   57487   77718  18007
# 1    MALE(2016)    83  1960   4394   7012  ...  30047  39319   54648   72211  15322
# 2     ALL(2016)   141  4645  10975  17216  ...  61026  80951  112135  149929  33399
# 3    MALE(2015)  2024  7952  13517  19826  ...  37482  40181   40442   25531   3127
# 4  FEMALE(2015)   661  4117   8410  13634  ...  36633  38976   39113   23127   2223
#
# [5 rows x 13 columns]

# %%
kcse
# Out:
#           Gender     A     A-     B+  ...     D+       D      D-      E
# 0   FEMALE(2016)    58   2685   6581  ...  41632   57487   77718  18007
# 1     MALE(2016)    83   1960   4394  ...  39319   54648   72211  15322
# 2      ALL(2016)   141   4645  10975  ...  80951  112135  149929  33399
# 3     MALE(2015)  2024   7952  13517  ...  40181   40442   25531   3127
# 4   FEMALE(2015)   661   4117   8410  ...  38976   39113   23127   2223
# 5      ALL(2015)  2685  12069  21927  ...  79157   79555   48658   5350
# 6     MALE(2006)   148    638   1195  ...   3418    3291    2635    834
# 7   FEMALE(2006)    69    242    446  ...   3519    3513    2909    897
# 8      ALL(2006)   217    880   1641  ...   6937    6804    5544   1731
# 9    MALE (2007)   110    563   1159  ...   3721    3493    2762    779
# 10  FEMALE(2007)    50    191    473  ...   3817    3730    2924    790
# 11     ALL(2007)   160    754   1632  ...   7538    7223    5686   1569
# ...

# %%
kcse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  21 non-null     object
#  1   A       21 non-null     int64
#  2   A-      21 non-null     int64
#  3   B+      21 non-null     int64
#  4   B       21 non-null     int64
#  5   B-      21 non-null     int64
#  6   C+      21 non-null     int64
#  7   C       21 non-null     int64
#  8   C-      21 non-null     int64
#  9   D+      21 non-null     int64
#  10  D       21 non-null     int64
#  11  D-      21 non-null     int64
#  12  E       21 non-null     int64
# dtypes: int64(12), object(1)
# memory usage: 2.3+ KB

# %%
kcse.sort_values(["Gender"], 
                    axis=0,
                    ascending=[False], 
                    inplace=True)
  
# displaying sorted data frame
print("\nAfter sorting:")
print(kcse)
# Out:
# After sorting:
#           Gender     A     A-     B+  ...     D+       D      D-      E
# 1     MALE(2016)    83   1960   4394  ...  39319   54648   72211  15322
# 3     MALE(2015)  2024   7952  13517  ...  40181   40442   25531   3127
# 18    MALE(2010)   182    892   1787  ...   4704    4561    3776   1306
# 15    MALE(2009)   138    628   1436  ...   4402    4336    3606   1257
# 12    MALE(2008)   102    698   1413  ...   3981    3942    3400   1379
# 6     MALE(2006)   148    638   1195  ...   3418    3291    2635    834
# 9    MALE (2007)   110    563   1159  ...   3721    3493    2762    779
# 0   FEMALE(2016)    58   2685   6581  ...  41632   57487   77718  18007
# 4   FEMALE(2015)   661   4117   8410  ...  38976   39113   23127   2223
# 19  FEMALE(2010)    97    344    744  ...   4734    4769    4012   1304
# 16  FEMALE(2009)    58    218    553  ...   4447    4514    3897   1326
# 13  FEMALE(2008)    66    274    596  ...   4043    4150    3593   1376
# ...

# %% [markdown]
# Lineplot

# %%
# draw lineplot
sns.lineplot(x="Gender", y="A", data=kcse)
  
# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')
  

# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# draw lineplot
sns.lineplot(x="Gender", y="A-", data=kcse)
  
# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')
  

# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# draw lineplot
sns.lineplot(x="Gender", y="B+", data=kcse)
  
# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')
  

# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# draw lineplot
sns.lineplot(x="Gender", y="B", data=kcse)
  
# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')
  

# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# draw lineplot
sns.lineplot(x="Gender", y="B-", data=kcse)
  
# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')
  

# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# draw lineplot
sns.lineplot(x="Gender", y="C+", data=kcse)
  
# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')
  

# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# draw lineplot
sns.lineplot(x="Gender", y="C", data=kcse)
  
# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')
  

# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# draw lineplot
sns.lineplot(x="Gender", y="C-", data=kcse)
  
# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')
  

# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# draw lineplot
sns.lineplot(x="Gender", y="D+", data=kcse)
  
# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')
  

# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# draw lineplot
sns.lineplot(x="Gender", y="D", data=kcse)
  
# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')
  

# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# draw lineplot
sns.lineplot(x="Gender", y="D-", data=kcse)
  
# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')
  

# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# draw lineplot
sns.lineplot(x="Gender", y="E", data=kcse)
  
# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')
  

# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# Scatterplot

# %%
sns.scatterplot(x='Gender', y='A', data=kcse)
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# Bar Chart

# %%
# Bar chart
plt.bar(kcse['Gender'], kcse['A'])
  
plt.title("Bar Chart")
  
# Setting the X and Y labels
plt.xlabel('Gender')
plt.ylabel('A')
  
# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# Bar chart
plt.bar(kcse['Gender'], kcse['A-'])
  
plt.title("Bar Chart")
  
# Setting the X and Y labels
plt.xlabel('Gender')
plt.ylabel('A-')
  
# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# Bar chart
plt.bar(kcse['Gender'], kcse['B+'])
  
plt.title("Bar Chart")
  
# Setting the X and Y labels
plt.xlabel('Gender')
plt.ylabel('B+')
  
# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# Bar chart
plt.bar(kcse['Gender'], kcse['B'])
  
plt.title("Bar Chart")
  
# Setting the X and Y labels
plt.xlabel('Gender')
plt.ylabel('B')
  
# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# Bar chart
plt.bar(kcse['Gender'], kcse['B-'])
  
plt.title("Bar Chart")
  
# Setting the X and Y labels
plt.xlabel('Gender')
plt.ylabel('B-')
  
# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# Bar chart
plt.bar(kcse['Gender'], kcse['C+'])
  
plt.title("Bar Chart")
  
# Setting the X and Y labels
plt.xlabel('Gender')
plt.ylabel('C+')
  
# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# Bar chart
plt.bar(kcse['Gender'], kcse['C'])
  
plt.title("Bar Chart")
  
# Setting the X and Y labels
plt.xlabel('Gender')
plt.ylabel('C')
  
# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# Bar chart
plt.bar(kcse['Gender'], kcse['D+'])
  
plt.title("Bar Chart")
  
# Setting the X and Y labels
plt.xlabel('Gender')
plt.ylabel('D+')
  
# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# Bar chart
plt.bar(kcse['Gender'], kcse['D'])
  
plt.title("Bar Chart")
  
# Setting the X and Y labels
plt.xlabel('Gender')
plt.ylabel('D')
  
# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# Bar chart
plt.bar(kcse['Gender'], kcse['D-'])
  
plt.title("Bar Chart")
  
# Setting the X and Y labels
plt.xlabel('Gender')
plt.ylabel('D-')
  
# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
# Bar chart
plt.bar(kcse['Gender'], kcse['E'])
  
plt.title("Bar Chart")
  
# Setting the X and Y labels
plt.xlabel('Gender')
plt.ylabel('E')
  
# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# Histogram

# %%
plt.hist(kcse['Gender'])
  
plt.title("Histogram")
  
# Adding the legends
ax = sns.countplot(x="Gender", data=kcse)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
